# %%
# Create a new set of 2,000 random latitudes and longitudes.
# Create Latitude and Longitude Combinations

# %%
# import the Pandas, Matplotlib, and NumPy dependencies in the first cell, and run the cell.

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Perform an API call with the OpenWeatherMap.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32d9b44c37f623141c5d4159e7a8d47e

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severodvinsk
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | nanchang
# Processing Record 4 of Set 1 | burns lake
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | gravdal
# Processing Record 9 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | dera bugti
# Processing Record 13 of Set 1 | almaznyy
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | tazovskiy
# Processing Record 16 of Set 1 | tromso
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | olafsvik
# Processing Record 20 of Set 1 | balma
# Processing Record 21 of Set 1 | chifeng
# Processing Record 22 of Set 1 | griffith
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | nanakuli
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | sitka
# Processing Record 29 of Set 1 | adrar
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | veraval
# Processing Record 33 of Set 1 | nelidovo
# Processing Record 34 of Set 1 | aasiaat
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | xining
# Processing Record 41 of Set 1 | glendive
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | woodward
# Processing Record 45 of Set 1 | bambous virieux
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | weligama
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | puerto madryn
# Processing Record 1 of Set 2 | alofi
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | hvolsvollur
# Processing Record 5 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 6 of Set 2 | port lincoln
# Processing Record 7 of Set 2 | puqi
# Processing Record 8 of Set 2 | ashta
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 2 | palmer
# Processing Record 12 of Set 2 | wolbrom
# Processing Record 13 of Set 2 | nha trang
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | esperance
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | eydhafushi
# Processing Record 19 of Set 2 | thinadhoo
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 2 | kruisfontein
# Processing Record 24 of Set 2 | langarud
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | svetlogorsk
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | teya
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | vestmannaeyjar
# Processing Record 33 of Set 2 | manuk mangkaw
# Processing Record 34 of Set 2 | darhan
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 2 | goderich
# Processing Record 37 of Set 2 | igarka
# Processing Record 38 of Set 2 | xuddur
# Processing Record 39 of Set 2 | saint-pierre
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | mweka
# Processing Record 43 of Set 2 | bose
# Processing Record 44 of Set 2 | pokhara
# Processing Record 45 of Set 2 | finote selam
# Processing Record 46 of Set 2 | benguela
# Processing Record 47 of Set 2 | doka
# Processing Record 48 of Set 2 | puerto penasco
# Processing Record 49 of Set 2 | thilogne
# City not found. Skipping...
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | santa cruz
# Processing Record 2 of Set 3 | senno
# Processing Record 3 of Set 3 | gulariya
# Processing Record 4 of Set 3 | mayo
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | lasa
# Processing Record 7 of Set 3 | soc trang
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | dejen
# Processing Record 10 of Set 3 | new bedford
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | nuuk
# Processing Record 14 of Set 3 | bourail
# Processing Record 15 of Set 3 | vendychany
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | ordzhonikidze
# Processing Record 18 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 3 | college
# Processing Record 20 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 3 | kavaratti
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | sungaipenuh
# Processing Record 24 of Set 3 | pevek
# Processing Record 25 of Set 3 | dingle
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | morlaix
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 3 | gombong
# Processing Record 30 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | trinidad
# Processing Record 32 of Set 3 | gat
# Processing Record 33 of Set 3 | barretos
# Processing Record 34 of Set 3 | bandarbeyla
# Processing Record 35 of Set 3 | shumyachi
# Processing Record 36 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 3 | husavik
# Processing Record 38 of Set 3 | zapolyarnyy
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | punto fijo
# Processing Record 43 of Set 3 | praia da vitoria
# Processing Record 44 of Set 3 | faanui
# Processing Record 45 of Set 3 | sangar
# Processing Record 46 of Set 3 | pangnirtung
# Processing Record 47 of Set 3 | youkounkoun
# Processing Record 48 of Set 3 | cayenne
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | careiro da varzea
# Processing Record 1 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 4 | nushki
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | xingyi
# Processing Record 5 of Set 4 | sao joao da barra
# Processing Record 6 of Set 4 | port hedland
# Processing Record 7 of Set 4 | haines junction
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | zhigalovo
# Processing Record 10 of Set 4 | berdigestyakh
# Processing Record 11 of Set 4 | lebu
# Processing Record 12 of Set 4 | alekseyevsk
# Processing Record 13 of Set 4 | am timan
# Processing Record 14 of Set 4 | punta alta
# Processing Record 15 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 4 | katsuura
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | verkhnyaya inta
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | chumikan
# Processing Record 22 of Set 4 | marquette
# Processing Record 23 of Set 4 | farmington
# Processing Record 24 of Set 4 | kishapu
# Processing Record 25 of Set 4 | kloulklubed
# Processing Record 26 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 4 | touros
# Processing Record 28 of Set 4 | phonhong
# Processing Record 29 of Set 4 | palora
# Processing Record 30 of Set 4 | nuristan
# Processing Record 31 of Set 4 | chabahar
# Processing Record 32 of Set 4 | pacific grove
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 35 of Set 4 | blytheville
# Processing Record 36 of Set 4 | mezen
# Processing Record 37 of Set 4 | naze
# Processing Record 38 of Set 4 | tyret pervaya
# Processing Record 39 of Set 4 | popondetta
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | henties bay
# Processing Record 42 of Set 4 | kurilsk
# Processing Record 43 of Set 4 | mindelo
# Processing Record 44 of Set 4 | neuquen
# Processing Record 45 of Set 4 | qunduz
# Processing Record 46 of Set 4 | gamba
# Processing Record 47 of Set 4 | komsomolskiy
# Processing Record 48 of Set 4 | umm kaddadah
# Processing Record 49 of Set 4 | posse
# Processing Record 50 of Set 4 | zhigansk
# Processing Record 1 of Set 5 | garden city
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | kolyvan
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | kozhva
# Processing Record 6 of Set 5 | korla
# Processing Record 7 of Set 5 | acarau
# Processing Record 8 of Set 5 | khatanga
# Processing Record 9 of Set 5 | viedma
# Processing Record 10 of Set 5 | homer
# Processing Record 11 of Set 5 | maniitsoq
# Processing Record 12 of Set 5 | yithion
# City not found. Skipping...
# Processing Record 13 of Set 5 | puerto ayora
# Processing Record 14 of Set 5 | bria
# Processing Record 15 of Set 5 | fuxin
# Processing Record 16 of Set 5 | tiruchchendur
# Processing Record 17 of Set 5 | itarema
# Processing Record 18 of Set 5 | saint-philippe
# Processing Record 19 of Set 5 | mukhen
# Processing Record 20 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 5 | high prairie
# Processing Record 22 of Set 5 | puquio
# Processing Record 23 of Set 5 | kaitangata
# Processing Record 24 of Set 5 | biak
# Processing Record 25 of Set 5 | jackson
# Processing Record 26 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 5 | longyearbyen
# Processing Record 28 of Set 5 | clyde river
# Processing Record 29 of Set 5 | kuching
# Processing Record 30 of Set 5 | pouembout
# Processing Record 31 of Set 5 | luderitz
# Processing Record 32 of Set 5 | kleck
# City not found. Skipping...
# Processing Record 33 of Set 5 | provideniya
# Processing Record 34 of Set 5 | bilibino
# Processing Record 35 of Set 5 | klaksvik
# Processing Record 36 of Set 5 | fort frances
# Processing Record 37 of Set 5 | jacqueville
# Processing Record 38 of Set 5 | hithadhoo
# Processing Record 39 of Set 5 | yerbogachen
# Processing Record 40 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 5 | grindavik
# Processing Record 42 of Set 5 | zhuhai
# Processing Record 43 of Set 5 | kropotkin
# Processing Record 44 of Set 5 | san quintin
# Processing Record 45 of Set 5 | kodiak
# Processing Record 46 of Set 5 | nouadhibou
# Processing Record 47 of Set 5 | mount gambier
# Processing Record 48 of Set 5 | pabbi
# Processing Record 49 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 6 | vanimo
# Processing Record 2 of Set 6 | constitucion
# Processing Record 3 of Set 6 | ambovombe
# Processing Record 4 of Set 6 | sembakung
# Processing Record 5 of Set 6 | manoel urbano
# Processing Record 6 of Set 6 | alyangula
# Processing Record 7 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 6 | nisia floresta
# Processing Record 9 of Set 6 | galesong
# Processing Record 10 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 6 | camacha
# Processing Record 12 of Set 6 | svetlyy
# Processing Record 13 of Set 6 | akhmim
# Processing Record 14 of Set 6 | nova russas
# Processing Record 15 of Set 6 | dunedin
# Processing Record 16 of Set 6 | cam ranh
# Processing Record 17 of Set 6 | muyezerskiy
# Processing Record 18 of Set 6 | nishihara
# Processing Record 19 of Set 6 | peniche
# Processing Record 20 of Set 6 | tuktoyaktuk
# Processing Record 21 of Set 6 | kimbe
# Processing Record 22 of Set 6 | canmore
# Processing Record 23 of Set 6 | mecca
# Processing Record 24 of Set 6 | kintampo
# Processing Record 25 of Set 6 | hualmay
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 6 | llangefni
# Processing Record 28 of Set 6 | bathsheba
# Processing Record 29 of Set 6 | mahebourg
# Processing Record 30 of Set 6 | turbat
# Processing Record 31 of Set 6 | bolobo
# Processing Record 32 of Set 6 | salaga
# Processing Record 33 of Set 6 | ponta do sol
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | najran
# Processing Record 36 of Set 6 | belen
# Processing Record 37 of Set 6 | malanje
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | arethousa
# Processing Record 40 of Set 6 | lagoa
# Processing Record 41 of Set 6 | port hardy
# Processing Record 42 of Set 6 | stornoway
# Processing Record 43 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 44 of Set 6 | salalah
# Processing Record 45 of Set 6 | barra do garcas
# Processing Record 46 of Set 6 | wewak
# Processing Record 47 of Set 6 | umtata
# Processing Record 48 of Set 6 | diego de almagro
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 6 | bani walid
# Processing Record 1 of Set 7 | puerto baquerizo moreno
# Processing Record 2 of Set 7 | malatya
# Processing Record 3 of Set 7 | koumac
# Processing Record 4 of Set 7 | san cristobal
# Processing Record 5 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 6 of Set 7 | axim
# Processing Record 7 of Set 7 | havelock
# Processing Record 8 of Set 7 | shahreza
# Processing Record 9 of Set 7 | parkes
# Processing Record 10 of Set 7 | szczytno
# Processing Record 11 of Set 7 | broome
# Processing Record 12 of Set 7 | maceio
# Processing Record 13 of Set 7 | deniliquin
# Processing Record 14 of Set 7 | brae
# Processing Record 15 of Set 7 | winslow
# Processing Record 16 of Set 7 | port augusta
# Processing Record 17 of Set 7 | cururupu
# Processing Record 18 of Set 7 | wote
# Processing Record 19 of Set 7 | pemberton
# Processing Record 20 of Set 7 | kamsack
# Processing Record 21 of Set 7 | dalbandin
# Processing Record 22 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 7 | fairbanks
# Processing Record 24 of Set 7 | fuerte olimpo
# Processing Record 25 of Set 7 | la ronge
# Processing Record 26 of Set 7 | half moon bay
# Processing Record 27 of Set 7 | atar
# Processing Record 28 of Set 7 | cedar city
# Processing Record 29 of Set 7 | san vicente
# Processing Record 30 of Set 7 | kelvington
# Processing Record 31 of Set 7 | labytnangi
# Processing Record 32 of Set 7 | oksfjord
# Processing Record 33 of Set 7 | ahipara
# Processing Record 34 of Set 7 | nevsehir
# Processing Record 35 of Set 7 | puerto colombia
# Processing Record 36 of Set 7 | yershov
# Processing Record 37 of Set 7 | hambantota
# Processing Record 38 of Set 7 | baykit
# Processing Record 39 of Set 7 | cabinda
# Processing Record 40 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 7 | comodoro rivadavia
# Processing Record 42 of Set 7 | bambanglipuro
# Processing Record 43 of Set 7 | aksu
# Processing Record 44 of Set 7 | gornoye loo
# Processing Record 45 of Set 7 | yar-sale
# Processing Record 46 of Set 7 | iqaluit
# Processing Record 47 of Set 7 | susanville
# Processing Record 48 of Set 7 | chegdomyn
# Processing Record 49 of Set 7 | tanjong tokong
# City not found. Skipping...
# Processing Record 50 of Set 7 | tilichiki
# Processing Record 1 of Set 8 | charcas
# Processing Record 2 of Set 8 | sinnamary
# Processing Record 3 of Set 8 | bubaque
# Processing Record 4 of Set 8 | necochea
# Processing Record 5 of Set 8 | qiongshan
# Processing Record 6 of Set 8 | chalmette
# Processing Record 7 of Set 8 | chengam
# Processing Record 8 of Set 8 | rabo de peixe
# Processing Record 9 of Set 8 | dakar
# Processing Record 10 of Set 8 | cabo san lucas
# Processing Record 11 of Set 8 | shuangyang
# Processing Record 12 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 8 | smidovich
# Processing Record 14 of Set 8 | merauke
# Processing Record 15 of Set 8 | asau
# Processing Record 16 of Set 8 | muisne
# Processing Record 17 of Set 8 | katangli
# Processing Record 18 of Set 8 | niksic
# Processing Record 19 of Set 8 | luganville
# Processing Record 20 of Set 8 | port macquarie
# Processing Record 21 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 8 | burnie
# Processing Record 23 of Set 8 | alta gracia
# Processing Record 24 of Set 8 | fort-shevchenko
# Processing Record 25 of Set 8 | udachnyy
# Processing Record 26 of Set 8 | giaginskaya
# Processing Record 27 of Set 8 | sergach
# Processing Record 28 of Set 8 | albina
# Processing Record 29 of Set 8 | salto de agua
# Processing Record 30 of Set 8 | kununurra
# Processing Record 31 of Set 8 | lindas
# Processing Record 32 of Set 8 | fort nelson
# Processing Record 33 of Set 8 | kawalu
# Processing Record 34 of Set 8 | huilong
# Processing Record 35 of Set 8 | seljord
# Processing Record 36 of Set 8 | rosario
# Processing Record 37 of Set 8 | macas
# Processing Record 38 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 39 of Set 8 | bad essen
# Processing Record 40 of Set 8 | talcahuano
# Processing Record 41 of Set 8 | coquimbo
# Processing Record 42 of Set 8 | eyl
# Processing Record 43 of Set 8 | tigil
# Processing Record 44 of Set 8 | santiago del estero
# Processing Record 45 of Set 8 | teluknaga
# Processing Record 46 of Set 8 | lerdo
# Processing Record 47 of Set 8 | port-gentil
# Processing Record 48 of Set 8 | ondjiva
# Processing Record 49 of Set 8 | beringovskiy
# Processing Record 50 of Set 8 | richards bay
# Processing Record 1 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | berezna
# Processing Record 3 of Set 9 | ramnagar
# Processing Record 4 of Set 9 | ballina
# Processing Record 5 of Set 9 | itoman
# Processing Record 6 of Set 9 | cherskiy
# Processing Record 7 of Set 9 | waldkirch
# Processing Record 8 of Set 9 | tura
# Processing Record 9 of Set 9 | elbistan
# Processing Record 10 of Set 9 | lata
# Processing Record 11 of Set 9 | shumskiy
# Processing Record 12 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 13 of Set 9 | balkanabat
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | ushtobe
# Processing Record 16 of Set 9 | iwanai
# Processing Record 17 of Set 9 | ust-maya
# Processing Record 18 of Set 9 | impfondo
# Processing Record 19 of Set 9 | suntar
# Processing Record 20 of Set 9 | do gonbadan
# Processing Record 21 of Set 9 | saint anthony
# Processing Record 22 of Set 9 | namatanai
# Processing Record 23 of Set 9 | qingyuan
# Processing Record 24 of Set 9 | bredy
# Processing Record 25 of Set 9 | vicuna
# Processing Record 26 of Set 9 | salinopolis
# Processing Record 27 of Set 9 | phan thiet
# Processing Record 28 of Set 9 | granja
# Processing Record 29 of Set 9 | snezhnogorsk
# Processing Record 30 of Set 9 | castres
# Processing Record 31 of Set 9 | george
# Processing Record 32 of Set 9 | saldanha
# Processing Record 33 of Set 9 | lethem
# Processing Record 34 of Set 9 | los llanos de aridane
# Processing Record 35 of Set 9 | upernavik
# Processing Record 36 of Set 9 | ancud
# Processing Record 37 of Set 9 | keti bandar
# Processing Record 38 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 39 of Set 9 | lalmanir hat
# City not found. Skipping...
# Processing Record 40 of Set 9 | severo-kurilsk
# Processing Record 41 of Set 9 | pathein
# Processing Record 42 of Set 9 | grand gaube
# Processing Record 43 of Set 9 | caravelas
# Processing Record 44 of Set 9 | cotonou
# Processing Record 45 of Set 9 | airai
# Processing Record 46 of Set 9 | mehamn
# Processing Record 47 of Set 9 | yalchiki
# City not found. Skipping...
# Processing Record 48 of Set 9 | garoua boulai
# Processing Record 49 of Set 9 | olinda
# Processing Record 50 of Set 9 | rudbar
# Processing Record 1 of Set 10 | jieshi
# Processing Record 2 of Set 10 | bud
# Processing Record 3 of Set 10 | vitim
# Processing Record 4 of Set 10 | chimore
# Processing Record 5 of Set 10 | cidreira
# Processing Record 6 of Set 10 | belsand
# Processing Record 7 of Set 10 | okitipupa
# Processing Record 8 of Set 10 | bachi-yurt
# Processing Record 9 of Set 10 | el tigre
# Processing Record 10 of Set 10 | fort collins
# Processing Record 11 of Set 10 | havoysund
# Processing Record 12 of Set 10 | kuusamo
# Processing Record 13 of Set 10 | torbay
# Processing Record 14 of Set 10 | pore
# Processing Record 15 of Set 10 | moindou
# Processing Record 16 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 10 | muhos
# Processing Record 18 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 10 | ginir
# Processing Record 20 of Set 10 | shimoni
# Processing Record 21 of Set 10 | cleethorpes
# Processing Record 22 of Set 10 | teguldet
# Processing Record 23 of Set 10 | coihaique
# Processing Record 24 of Set 10 | nosivka
# Processing Record 25 of Set 10 | alice springs
# Processing Record 26 of Set 10 | kamen-na-obi
# Processing Record 27 of Set 10 | cervo
# Processing Record 28 of Set 10 | pisco
# Processing Record 29 of Set 10 | tabou
# Processing Record 30 of Set 10 | fukue
# Processing Record 31 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 10 | betsiamites
# Processing Record 33 of Set 10 | manado
# Processing Record 34 of Set 10 | saint george
# Processing Record 35 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 36 of Set 10 | leninsk
# Processing Record 37 of Set 10 | urumqi
# Processing Record 38 of Set 10 | marawi
# Processing Record 39 of Set 10 | jacareacanga
# Processing Record 40 of Set 10 | kuytun
# Processing Record 41 of Set 10 | termiz
# Processing Record 42 of Set 10 | nioki
# Processing Record 43 of Set 10 | lao cai
# Processing Record 44 of Set 10 | lampang
# Processing Record 45 of Set 10 | usinsk
# Processing Record 46 of Set 10 | anadyr
# Processing Record 47 of Set 10 | mackay
# Processing Record 48 of Set 10 | cap-aux-meules
# Processing Record 49 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 50 of Set 10 | vila
# Processing Record 1 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 11 | jubayl
# City not found. Skipping...
# Processing Record 3 of Set 11 | guanica
# Processing Record 4 of Set 11 | bay roberts
# Processing Record 5 of Set 11 | kieta
# Processing Record 6 of Set 11 | lavrentiya
# Processing Record 7 of Set 11 | ixtapa
# Processing Record 8 of Set 11 | tandil
# Processing Record 9 of Set 11 | srednekolymsk
# Processing Record 10 of Set 11 | san javier
# Processing Record 11 of Set 11 | black river
# Processing Record 12 of Set 11 | macapa
# Processing Record 13 of Set 11 | chilliwack
# Processing Record 14 of Set 11 | eenhana
# Processing Record 15 of Set 11 | mbini
# Processing Record 16 of Set 11 | amatlan
# City not found. Skipping...
# Processing Record 17 of Set 11 | jalu
# Processing Record 18 of Set 11 | biskamzha
# Processing Record 19 of Set 11 | bassano
# Processing Record 20 of Set 11 | buala
# Processing Record 21 of Set 11 | hohhot
# Processing Record 22 of Set 11 | bonthe
# Processing Record 23 of Set 11 | maarianhamina
# Processing Record 24 of Set 11 | mapiripan
# Processing Record 25 of Set 11 | staritsa
# Processing Record 26 of Set 11 | sena madureira
# Processing Record 27 of Set 11 | neryungri
# Processing Record 28 of Set 11 | kargasok
# Processing Record 29 of Set 11 | grants pass
# Processing Record 30 of Set 11 | bonavista
# Processing Record 31 of Set 11 | oktyabrskiy
# Processing Record 32 of Set 11 | antofagasta
# Processing Record 33 of Set 11 | okhotsk
# Processing Record 34 of Set 11 | altea
# Processing Record 35 of Set 11 | pitimbu
# Processing Record 36 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 11 | toora-khem
# Processing Record 38 of Set 11 | hofn
# Processing Record 39 of Set 11 | meulaboh
# Processing Record 40 of Set 11 | pital
# Processing Record 41 of Set 11 | arlit
# Processing Record 42 of Set 11 | takoradi
# Processing Record 43 of Set 11 | flinders
# Processing Record 44 of Set 11 | qaqortoq
# Processing Record 45 of Set 11 | naryan-mar
# Processing Record 46 of Set 11 | la palma
# Processing Record 47 of Set 11 | angoche
# Processing Record 48 of Set 11 | waipawa
# Processing Record 49 of Set 11 | jardim
# Processing Record 50 of Set 11 | kiama
# Processing Record 1 of Set 12 | maningrida
# Processing Record 2 of Set 12 | temirtau
# Processing Record 3 of Set 12 | aquiraz
# Processing Record 4 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 5 of Set 12 | kavieng
# Processing Record 6 of Set 12 | talara
# Processing Record 7 of Set 12 | teknaf
# Processing Record 8 of Set 12 | paamiut
# Processing Record 9 of Set 12 | saint-alexandre
# Processing Record 10 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 12 | nadym
# Processing Record 12 of Set 12 | leningradskiy
# Processing Record 13 of Set 12 | rock springs
# Processing Record 14 of Set 12 | codrington
# Processing Record 15 of Set 12 | jimenez
# Processing Record 16 of Set 12 | bantry
# Processing Record 17 of Set 12 | breyten
# Processing Record 18 of Set 12 | polva
# Processing Record 19 of Set 12 | beihai
# Processing Record 20 of Set 12 | nizhneangarsk
# Processing Record 21 of Set 12 | howard springs
# Processing Record 22 of Set 12 | egvekinot
# Processing Record 23 of Set 12 | rocha
# Processing Record 24 of Set 12 | san ramon de la nueva oran
# Processing Record 25 of Set 12 | umarkot
# Processing Record 26 of Set 12 | nanton
# Processing Record 27 of Set 12 | san andres
# Processing Record 28 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 29 of Set 12 | walvis bay
# Processing Record 30 of Set 12 | gummidipundi
# Processing Record 31 of Set 12 | scarborough
# Processing Record 32 of Set 12 | denpasar
# Processing Record 33 of Set 12 | liusha
# Processing Record 34 of Set 12 | muroto
# Processing Record 35 of Set 12 | khovu-aksy
# Processing Record 36 of Set 12 | mtinko
# Processing Record 37 of Set 12 | tautira
# Processing Record 38 of Set 12 | moyale
# Processing Record 39 of Set 12 | sabang
# Processing Record 40 of Set 12 | markala
# Processing Record 41 of Set 12 | san francisco
# Processing Record 42 of Set 12 | otorohanga
# Processing Record 43 of Set 12 | luwuk
# Processing Record 44 of Set 12 | krasnaya gora
# Processing Record 45 of Set 12 | broken hill
# Processing Record 46 of Set 12 | ugoofaaru
# Processing Record 47 of Set 12 | sosnovo-ozerskoye
# Processing Record 48 of Set 12 | harper
# Processing Record 49 of Set 12 | maromitsa
# Processing Record 50 of Set 12 | peachland
# Processing Record 1 of Set 13 | seguela
# Processing Record 2 of Set 13 | marrakesh
# Processing Record 3 of Set 13 | shingu
# Processing Record 4 of Set 13 | perene
# Processing Record 5 of Set 13 | carbonia
# Processing Record 6 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 13 | chilca
# Processing Record 8 of Set 13 | tessalit
# Processing Record 9 of Set 13 | hingorja
# Processing Record 10 of Set 13 | coroico
# Processing Record 11 of Set 13 | kharp
# Processing Record 12 of Set 13 | chivilcoy
# Processing Record 13 of Set 13 | fairview
# Processing Record 14 of Set 13 | palu
# Processing Record 15 of Set 13 | luocheng
# Processing Record 16 of Set 13 | sambava
# Processing Record 17 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 13 | tezpur
# Processing Record 19 of Set 13 | okha
# Processing Record 20 of Set 13 | prainha
# Processing Record 21 of Set 13 | hamilton
# Processing Record 22 of Set 13 | kutoarjo
# Processing Record 23 of Set 13 | manokwari
# Processing Record 24 of Set 13 | koch bihar
# Processing Record 25 of Set 13 | gasa
# Processing Record 26 of Set 13 | taoudenni
# Processing Record 27 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 13 | general roca
# Processing Record 29 of Set 13 | kayanga
# Processing Record 30 of Set 13 | sorland
# Processing Record 31 of Set 13 | abu dhabi
# Processing Record 32 of Set 13 | paredon
# Processing Record 33 of Set 13 | rio grande
# Processing Record 34 of Set 13 | baltay
# Processing Record 35 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 13 | hirara
# Processing Record 37 of Set 13 | warrnambool
# Processing Record 38 of Set 13 | sibu
# Processing Record 39 of Set 13 | santa maria
# Processing Record 40 of Set 13 | ilek
# Processing Record 41 of Set 13 | byron bay
# Processing Record 42 of Set 13 | mayumba
# Processing Record 43 of Set 13 | svetlaya
# Processing Record 44 of Set 13 | plavinas
# Processing Record 45 of Set 13 | veinticinco de mayo
# Processing Record 46 of Set 13 | paciran
# Processing Record 47 of Set 13 | sioux lookout
# Processing Record 48 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 13 | taree
# Processing Record 50 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 1 of Set 14 | porbandar
# Processing Record 2 of Set 14 | karratha
# Processing Record 3 of Set 14 | ponta delgada
# Processing Record 4 of Set 14 | taos
# Processing Record 5 of Set 14 | sakakah
# Processing Record 6 of Set 14 | andenes
# Processing Record 7 of Set 14 | salaberry-de-valleyfield
# Processing Record 8 of Set 14 | quatre cocos
# Processing Record 9 of Set 14 | bonfim
# Processing Record 10 of Set 14 | shujalpur
# Processing Record 11 of Set 14 | kamenka
# Processing Record 12 of Set 14 | puerto el triunfo
# Processing Record 13 of Set 14 | goundam
# Processing Record 14 of Set 14 | arys
# Processing Record 15 of Set 14 | porto novo
# Processing Record 16 of Set 14 | tahta
# Processing Record 17 of Set 14 | qazvin
# Processing Record 18 of Set 14 | emmett
# Processing Record 19 of Set 14 | nurota
# Processing Record 20 of Set 14 | vila velha
# Processing Record 21 of Set 14 | vieux-habitants
# Processing Record 22 of Set 14 | carlisle
# Processing Record 23 of Set 14 | margate
# Processing Record 24 of Set 14 | shar
# Processing Record 25 of Set 14 | taft
# Processing Record 26 of Set 14 | moose factory
# Processing Record 27 of Set 14 | maliq
# Processing Record 28 of Set 14 | vostok
# Processing Record 29 of Set 14 | shinpokh
# Processing Record 30 of Set 14 | vao
# Processing Record 31 of Set 14 | nyahururu
# Processing Record 32 of Set 14 | zonalnaya stantsiya
# Processing Record 33 of Set 14 | geraldton
# Processing Record 34 of Set 14 | opunake
# Processing Record 35 of Set 14 | vallenar
# Processing Record 36 of Set 14 | ipueiras
# Processing Record 37 of Set 14 | rangpo
# Processing Record 38 of Set 14 | gigmoto
# Processing Record 39 of Set 14 | kholuy
# Processing Record 40 of Set 14 | spornoye
# Processing Record 41 of Set 14 | panambi
# Processing Record 42 of Set 14 | portland
# Processing Record 43 of Set 14 | san policarpo
# Processing Record 44 of Set 14 | mizdah
# Processing Record 45 of Set 14 | tuatapere
# Processing Record 46 of Set 14 | kazachinskoye
# Processing Record 47 of Set 14 | itambacuri
# Processing Record 48 of Set 14 | ahuimanu
# Processing Record 49 of Set 14 | san juan
# Processing Record 50 of Set 14 | farafangana
# Processing Record 1 of Set 15 | beloha
# Processing Record 2 of Set 15 | bagdarin
# Processing Record 3 of Set 15 | seymchan
# Processing Record 4 of Set 15 | pietra ligure
# Processing Record 5 of Set 15 | yaan
# Processing Record 6 of Set 15 | samarai
# Processing Record 7 of Set 15 | nelson bay
# Processing Record 8 of Set 15 | puerto del rosario
# Processing Record 9 of Set 15 | jiangyou
# Processing Record 10 of Set 15 | horsham
# Processing Record 11 of Set 15 | ozark
# Processing Record 12 of Set 15 | kandrian
# Processing Record 13 of Set 15 | los andes
# Processing Record 14 of Set 15 | ambilobe
# Processing Record 15 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 15 | deputatskiy
# Processing Record 17 of Set 15 | djibo
# Processing Record 18 of Set 15 | ha tinh
# Processing Record 19 of Set 15 | paita
# Processing Record 20 of Set 15 | konstantinovka
# Processing Record 21 of Set 15 | borujerd
# Processing Record 22 of Set 15 | oakdale
# Processing Record 23 of Set 15 | maues
# Processing Record 24 of Set 15 | kidodi
# Processing Record 25 of Set 15 | flin flon
# Processing Record 26 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 27 of Set 15 | sheridan
# Processing Record 28 of Set 15 | brazzaville
# Processing Record 29 of Set 15 | rundu
# Processing Record 30 of Set 15 | tarsus
# Processing Record 31 of Set 15 | tome
# Processing Record 32 of Set 15 | kaeo
# Processing Record 33 of Set 15 | malm
# Processing Record 34 of Set 15 | vieste
# Processing Record 35 of Set 15 | imbituba
# Processing Record 36 of Set 15 | sao felix do xingu
# Processing Record 37 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 15 | churapcha
# Processing Record 39 of Set 15 | magadan
# Processing Record 40 of Set 15 | campbell river
# Processing Record 41 of Set 15 | nizhniye vyazovyye
# Processing Record 42 of Set 15 | havre-saint-pierre
# Processing Record 43 of Set 15 | balkhash
# Processing Record 44 of Set 15 | kudahuvadhoo
# Processing Record 45 of Set 15 | along
# Processing Record 46 of Set 15 | aranos
# Processing Record 47 of Set 15 | brigantine
# Processing Record 48 of Set 15 | seoul
# Processing Record 49 of Set 15 | pervomayskoye
# Processing Record 50 of Set 15 | bichena
# Processing Record 1 of Set 16 | west odessa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFram
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severodvinsk      RU  64.5635   39.8302      6.91        76          11
# 1     Jamestown      US  42.0970  -79.2353     18.72        53           0
# 2      Nanchang      CN  28.6833  115.8833     47.46        59           3
# 3    Burns Lake      CA  54.2331 -125.7533     29.62        99         100
# 4        Hobart      AU -42.8794  147.3294     69.03        70          75
# 5       Mataura      NZ -46.1927  168.8643     56.48        93          96
# 6    Bredasdorp      ZA -34.5322   20.0403     63.72        68          99
# 7       Gravdal      NO  68.1214   13.5031     39.88        97         100
# 8     Busselton      AU -33.6500  115.3333     83.34        37           0
# 9    Chokurdakh      RU  70.6333  147.9167    -22.05        99         100
#
#    Wind Speed Current Description
# 0       14.58          few clouds
# 1        5.99           clear sky
# 2        3.02           clear sky
# 3        3.51     overcast clouds
# 4        1.01       broken clouds
# 5       11.68     overcast clouds
# 6        4.61     overcast clouds
# 7       35.97     overcast clouds
# 8        4.72           clear sky
# 9        3.29     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
